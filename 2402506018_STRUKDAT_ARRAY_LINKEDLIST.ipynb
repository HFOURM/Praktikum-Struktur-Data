# %% [markdown]
# <a href="https://colab.research.google.com/github/HFOURM/Praktikum-Struktur-Data/blob/main/2402506018_STRUKDAT_ARRAY_LINKEDLIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Implementasi Singly Linked List

# %%
# Definisi Node dalam Linked List
class TaskNode:
    def __init__(self, task_name):
        self.task_name = task_name
        self.next = None
# Definisi Linked List untuk Daftar Tugas
class TaskList:
    def __init__(self):
        self.head = None # Awalnya tidak ada tugas (daftar kosong)

    # Menambahkan tugas ke Linked List
    def add_task(self, task_name):
        new_task = TaskNode(task_name)
        if not self.head:
            self.head = new_task # Jika list kosong, tugas pertama menjadi head
        else:
            current = self.head
            while current.next: # Mencari node terakhir dalam list
                current = current.next
            current.next = new_task # Menambahkan tugas di akhir list
    # Menampilkan daftar tugas
    def show_tasks(self):
        if not self.head:
            print("\nTidak ada tugas hari ini!")

        print("\n Daftar Tugas Hari Ini:")
        current = self.head
        count = 1
        while current:
            print(f"{count}. {current.task_name}")
            current = current.next
            count += 1

# ===== Program Utama (Main) ===== #

# Membuat objek daftar tugas
task_list = TaskList()

# Meminta pengguna memasukkan jumlah tugas
num_tasks = int(input("Masukkan jumlah tugas hari ini: "))

# Loop untuk memasukkan tugas ke dalam Linked List
for _ in range(num_tasks):
    task_name = input("Masukkan nama tugas: ")
    task_list.add_task(task_name)

# Menampilkan hasil daftar tugas
task_list.show_tasks()
# Out:
# Masukkan jumlah tugas hari ini: 2
# Masukkan nama tugas: a
# Masukkan nama tugas: v
#
#  Daftar Tugas Hari Ini:
# 1. a
# 2. v

# %% [markdown]
# **Latihan 1**

# %%
# Definisi Node dalam Linked List
class MatkulNode:
    def __init__(self, nama_matkul):
        self.nama_matkul = nama_matkul
        self.next = None
# Definisi Linked List untuk Daftar Tugas
class MatkulList:
    def __init__(self):
        self.head = None # Awalnya tidak ada Matkul (daftar kosong)

    # Menambahkan Matkul ke Linked List
    def add_matkul(self, nama_matkul):
        matkul_baru = MatkulNode(nama_matkul)
        if not self.head:
            self.head = matkul_baru # Jika list kosong, matkul pertama menjadi head
        else:
            current = self.head
            while current.next: # Mencari node terakhir dalam list
                current = current.next
            current.next = matkul_baru# Menambahkan matkul di akhir list
    # Menampilkan jadwal matkul
    def show_matkul(self):
        if not self.head:
            print("\nTidak ada matkul hari ini!")

        print("\n Jadwal Mata Kuliah Hari Ini:")
        current = self.head
        count = 1
        while current:
            print(f"{count}. {current.nama_matkul}")
            current = current.next
            count += 1

# ===== Program Utama (Main) ===== #

# Membuat objek jadwal matkul
list_matkul = MatkulList()

# Meminta pengguna memasukkan jumlah Matkul
jumlah_matkul = int(input("Masukkan jumlah Matkul Hari Jumat: "))

# Loop untuk memasukkan matkul ke dalam Linked List
for _ in range(jumlah_matkul):
    nama_matkul = input("Masukkan nama matkul: ")
    list_matkul.add_matkul(nama_matkul)

# Menampilkan hasil jadwal matkul
list_matkul.show_matkul()
# Out:
# Masukkan jumlah Matkul Hari Jumat: 2
# Masukkan nama matkul: 1
# Masukkan nama matkul: 2
#
#  Jadwal Mata Kuliah Hari Ini:
# 1. 1
# 2. 2

# %% [markdown]
# # Implementasi Doubly Link List

# %%
# Definisi Node dalam Doubly Link List
class PageNode:
    def __init__(self, url):
        self.url = url # URL halaman web
        self.next = None # Pointer ke halaman berikutnya
        self.prev = None # Pointer ke halaman sebelumnya

# Definisi Doubly Linked List untuk Riwayat Peramban
class BrowserHistory:
    def __init__(self):
        self.current = None # Pointer ke halaman yang sedang dibuka

    # Menambahkan halaman baru ke dalam riwayat
    def visit_page(self,url):
        new_page = PageNode(url)
        if not self.current:
            self.current = new_page # Jika riwayat kosong, halaman ini menjadi halaman pertama
        else:
            new_page.prev = self.current
            self.current.next = new_page
            self.current = new_page # Pinidahkan posisi ke halaman baru

    # Menampilkan riwayat kunjungan
    def show_history(self):
        if not self.current:
            print("\n Riwayat kosong.")
            return

        print("\nRiwayat Peramban web:")
        temp = self.current
        while temp.prev: # Kembali ke halaman pertama
            temp = temp.prev

        count = 1
        while temp:
            print(f"{count}. {temp.url}")
            temp = temp.next
            count += 1
    # Navigasi mundur ke halaman sebelumnya
    def go_back(self):
        if self.current and self.current.prev:
            self.current = self.current.prev
            print(f"\n Anda kembali ke: {self.current.url}")
        else:
            print("\n Tidak bisa kembali, ini adalah halaman pertama!")

    # Navigasi maju ke halaman berikutnya
    def go_forward(self):
        if self.current and self.current.next:
            self.current = self.current.next
            print(f"\n Anda maju ke: {self.current.url}")
        else:
            print("\n Tidak bisa maju, ini adalah halaman terakhir!")

# ===== Program Utama (Main) ===== #

# Membuat objek riwayat peramban
history = BrowserHistory()

# Meminta pengguna memasukkan jumlah halaman yang dikunjungi
num_pages = int (input("\nMasukkan jumlah halaman yang dikunjungi:"))

# Loop untuk memasukkan URL halaman ke dalam Doubly Linked List
for i in range(1, num_pages + 1):
    url = input(f"\nMasukkan URL halaman ke-{i}: ")
    history.visit_page(url)

# Menampilkan riwayat yang telah dimasukkan
history.show_history()

# Menu navigasi pengguna
while True:
    command = input("\n Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar. \nMauskkan perintah: ").lower()

    if command == 'b':
        history.go_back()
    elif command == 'f':
        history.go_forward()
    elif command == 'x':
        print("\n Keluar dari riwayat peramban.")
        break
    else:
        print("\n Perintah tidak dikenal.")
# Out:
# Masukkan jumlah halaman yang dikunjungi:2
#
# Masukkan URL halaman ke-1: a
#
# Masukkan URL halaman ke-2: v
#
# Riwayat Peramban web:
# 1. a
# 2. v
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Mauskkan perintah: b
#
#  Anda kembali ke: a
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Mauskkan perintah: f
#
#  Anda maju ke: v
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Mauskkan perintah: x
#
#  Keluar dari riwayat peramban.

# %% [markdown]
# **Latihan 2**

# %%
# Definisi Node dalam Doubly Link List
class FolderNode:
    def __init__(self, nama_folder):
        self.nama_folder = nama_folder # nama folder
        self.next = None # Pointer ke folder berikutnya
        self.prev = None # Pointer ke folder sebelumnya

# Definisi Doubly Linked List untuk Riwayat Peramban
class FileExplorerHistory:
    def __init__(self):
        self.current = None # Pointer ke folder yang sedang dibuka

    # Menambahkan folder baru ke dalam riwayat
    def visit_Folder(self, nama_folder):
        folder_baru = FolderNode(nama_folder)
        if not self.current:
            self.current = folder_baru # Jika riwayat kosong, folder  ini menjadi folder pertama
        else:
            folder_baru.prev = self.current
            self.current.next = folder_baru
            self.current = folder_baru # Pinidahkan posisi ke folder baru

    # Menampilkan riwayat kunjungan
    def show_history(self):
        if not self.current:
            print("\n Riwayat navigasi kosong.")
            return

        print("\nRiwayat Navigasi File Explorer:")
        temp = self.current
        while temp.prev: # Kembali ke folder pertama
            temp = temp.prev

        count = 1
        while temp:
            print(f"{count}. {temp.nama_folder}")
            temp = temp.next
            count += 1
    # Navigasi mundur ke folder sebelumnya
    def go_back(self):
        if self.current and self.current.prev:
            self.current = self.current.prev
            print(f"\n Anda kembali ke: {self.current.nama_folder}")
        else:
            print("\n Tidak bisa kembali, ini adalah folder pertama!")

    # Navigasi maju ke folder berikutnya
    def go_forward(self):
        if self.current and self.current.next:
            self.current = self.current.next
            print(f"\n Anda maju ke: {self.current.nama_folder}")
        else:
            print("\n Tidak bisa maju, ini adalah folder terakhir!")

# ===== Program Utama (Main) ===== #

# Membuat objek riwayat FileExplorer
history = FileExplorerHistory()

# Meminta pengguna memasukkan jumlah folder yang dikunjungi
jumlah_folder = int (input("\nMasukkan jumlah folder yang dikunjungi:"))

# Loop untuk memasukkan nama folder ke dalam Doubly Linked List
for i in range(1, jumlah_folder + 1):
    nama_folder = input(f"\nMasukkan Nama Folders ke-{i}: ")
    history.visit_Folder(nama_folder)

# Menampilkan riwayat yang telah dimasukkan
history.show_history()

# Menu navigasi pengguna
while True:
    command = input("\n Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar. \nMauskkan perintah: ").lower()

    if command == 'b':
        history.go_back()
    elif command == 'f':
        history.go_forward()
    elif command == 'x':
        print("\n Keluar dari navigasi File Explorer.")
        break
    else:
        print("\n Perintah tidak dikenal.")
# Out:
# Masukkan jumlah folder yang dikunjungi:2
#
# Masukkan Nama Folders ke-1: 1
#
# Masukkan Nama Folders ke-2: 2
#
# Riwayat Navigasi File Explorer:
# 1. 1
# 2. 2
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Mauskkan perintah: f
#
#  Tidak bisa maju, ini adalah folder terakhir!
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Mauskkan perintah: b
#
#  Anda kembali ke: 1
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Mauskkan perintah: f
#
#  Anda maju ke: 2
#
#  Tekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.
# Mauskkan perintah: x
#
#  Keluar dari navigasi File Explorer.

# %% [markdown]
# # Impelementasi Circular Link List

# %%
# Definisi Node dalam Circular Linked List
class SongNode:
    def __init__(self, title):
        self.title = title # Menyimpan judul lagu
        self.next =  None # Pointer ke lagu berikutnya

# Definisi Circular Linked List untuk Playlist Lagu
class Playlist:
    def __init__(self):
        self.current = None # Lagu yang sedang diputar

    # Menambahkan lagu ke dalam playlist
    def add_song(self, title):
        new_song = SongNode (title)
        if not self.current:
            self.current = new_song
            self.current.next = self.current # Menghubungkan ke dirinya sendiri (Circular)
        else:
            temp = self.current
            while temp.next != self.current: # Mencari lagu terakhir
                temp = temp.next
            temp.next = new_song # Mencari lagu di akhir
            new_song.next = self.current # Menghubungkan kembali ke awal

    # Menampilkan daftar lagu dalam playlist
    def show_playlist(self):
        if not self.current:
            print("\n Playlist Kosong!")
            return

        print("\n Playlist Lagu Anda:")
        temp = self.current
        count = 1
        while True:
            print(f"{count}. {temp.title}")
            temp = temp.next
            count += 1
            if temp == self.current: # Berhenti jika sudah kembali ke awal
                break
    # Memutar lagu berikutnya dalam play list
    def next_song(self):
        if self.current:
            self.current = self.current.next
            print(f"\n Memutar :{self.current.title}")

# ===== Program Utama (Main) ===== #

# Membuat objek playlist
playlist = Playlist()

# Meminta pengguna memasukkan jumlah lagu
num_songs = int(input("\nMasukkan jumlah lagu dalam playlist: "))

# Loop untuk memasukkan lagu ke dalam Circular Linked List
for i in range(1, num_songs + 1):
    title = input(f"\nMasukkan judul lagu ke-{i}: ")
    playlist.add_song(title)

# Menampilakn daftar lagu
playlist.show_playlist()

# Menu navigasi pengguna
while True:
    command = input("\n Tekan 'n' untuk memutar lagu berikutnya, Tekan 'x' untuk keluar. \n Masukkan perintah: ").lower()

    if command == 'n':
        playlist.next_song()
    elif command == 'x':
        print("\n Keluar dari pemutar musik.")
        break
    else:
        print("\n Perintah tidak dikenal.")
# Out:
# Masukkan jumlah lagu dalam playlist: 3
#
# Masukkan judul lagu ke-1: Pompeii
#
# Masukkan judul lagu ke-2: Nina
#
# Masukkan judul lagu ke-3: Resah Jadi Luka
#
#  Playlist Lagu Anda:
# 1. Pompeii
# 2. Nina
# 3. Resah Jadi Luka
#
#  Tekan 'n' untuk memutar lagu berikutnya, Tekan 'x' untuk keluar.
#  Masukkan perintah: n
#
#  Memutar :Nina
#
#  Tekan 'n' untuk memutar lagu berikutnya, Tekan 'x' untuk keluar.
#  Masukkan perintah: x
#
#  Keluar dari pemutar musik.

# %% [markdown]
# # Operasi Dasar Pada Linked List

# %%
# Definisi Node dalam Singly Linked List
class Node:
    def __init__(self, data):
        self.data = data # Menyimpan nilai node
        self.next = None # Pointer ke node berikutnya

# Definisi Singly Linked List dengan Berbagai Operasi
class LinkedList:
    def __init__(self):
        self.head = None # Awalmua, daftar kosong

    # Menambahkan elemen di awal
    def add_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    # Menambahkan elemen di akhir
    def add_at_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node

    # Menambahkan elemen di posisi tertentu
    def add_at_position(self, data, position):
        if position < 0:
            print(" Posisi tidak valid!")
            return
        new_node = Node(data)
        if position == 0:
            self.add_at_beginning(data)
            return
        temp = self.head
        for _ in range (position - 1):
            if not temp:
                print(" Posisi melebihi panjang daftar!")
                return
            temp = temp.next
        new_node.next = temp.next
        temp.next = new_node

    # Menghapus elemen di awal
    def delete_at_beginning(self):
        if not self.head:
            print(" Daftar kosong, tidak ada elemen yang bisa dihapus!")
            return
        self.head = self.head.next

    # Menghapus elemen di akhir
    def delete_at_end(self):
        if not self.head:
            print(" Daftar kosong, tidak ada elemen yang bisa dihapus!")
            return
        if not self.head.next:
            self.head = None
            return
        temp = self.head
        while temp.next.next:
            temp = temp.next
        temp.next = None

    # Menghapus elemen di posisi tertentu
    def delete_at_position(self, position):
        if not self.head:
            print(" Daftar kosong, tidak ada elemen yang bisa dihapus!")
            return
        if position == 0:
            self.head = self.head.next
            return
        temp = self.head
        for _ in range (position - 1):
            if not temp.next:
                print(" Posisi tidak ditemukan!")
                return
            temp = temp.next
        temp.next = temp.next.next

    # Mencari elemen dalam Linked List
    def search(self, key):
        temp = self.head
        while temp:
            if temp.data == key:
                print(f" Elemen {key} di temukan dalam daftar!")
                return
            temp = temp.next
        print(f" Elemen {key} tidak ditemukan dalam daftar!")

    # Membalik (reverse) Link List
    def reverse(self):
        prev = None
        current = self.head
        while current:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
        self.head = prev

    # Menampilkan Link list
    def display(self):
        if not self.head:
            print(" Daftar kosong!")
            return
        temp = self.head
        while temp:
            print(temp.data, end = " -> ")
            temp = temp.next
        print("None")

# ===== Program Utama (Main) ===== #

# Membuat objek Link List
ll = LinkedList()

# Meminta pengguna memasukkan elemen awal
num_element =  int(input("\nMasukkan jumlah elemen dalam daftar: "))
for i in range(num_element):
    data = int(input(f"Masukkan elemen ke-{i + 1}: "))
    ll.add_at_end(data)

# Menu Operasi Linked List
while True:
    print("\nPilih Operasi:")
    print("1. Tambah elemen di awal")
    print("2. Tambah elemen di akhir")
    print("3. Tambah elemen di posisi tertentu")
    print("4. Hapus elemen di awal")
    print("5. Hapus elemen di akhir")
    print("6. Hapus elemen di posisi tertentu")
    print("7. Cari elemen dalam daftar")
    print("8. Balikkan daftar")
    print("9. Tampilkan daftar")
    print("0. Keluar")

    choice = int(input("Masukkan pilihan Anda: "))

    if choice == 1:
        data = int(input("Masukkan data yang ingin ditambahkan di awal: "))
        ll.add_at_beginning(data)
    elif choice == 2:
        data = int(input("Masukkan data yang ingin ditambahkan di akhir: "))
        ll.add_at_end(data)
    elif choice == 3:
        position = int(input("Masukkan posisi untuk menambahkan data: "))
        data = int(input("Masukkan data yang ingin ditambahkan: "))
        ll.add_at_position(data, position)
    elif choice == 4:
        ll.delete_at_beginning()
    elif choice == 5:
        ll.delete_at_end()
    elif choice == 6:
        position = int(input("Masukkan posisi elemen yang ingin dihapus:"))
        ll.delete_at_position(position)
    elif choice == 7:
        key = int(input("Masukkan elemen yang ingin dicari: "))
        ll.search(key)
    elif choice == 8:
        ll.reverse()
        print("Daftar berhasil dibalik!")
    elif choice == 9:
        ll.display()
    elif choice == 0:
        print("\nKeluar dari program.")
        break
    else:
        print("\nPilihan tidak valid, Silakan coba lagi!")
# Out:
# Masukkan jumlah elemen dalam daftar: 2
# Masukkan elemen ke-1: 1
# Masukkan elemen ke-2: 2
#
# Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
# Masukkan pilihan Anda: 0
#
# Keluar dari program.

# %% [markdown]
# **Latihan 3**
